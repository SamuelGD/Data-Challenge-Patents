# %% [markdown]
# # Prédiction de l'obtention d'un brevet
# ### Samuel Guilhem-Ducléon

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# We extract the csv files

train_fname = 'train.csv'
test_fname = 'test.csv'
dataframe = pd.read_csv(train_fname, sep=';')
df_test = pd.read_csv(test_fname, sep=';')

# %%
dataframe.head(5)
# Out:
#      VOIE_DEPOT COUNTRY SOURCE_BEGIN_MONTH  APP_NB  APP_NB_PAYS  APP_NB_TYPE  \
# 0      EURO-PCT      US                 D0       1            1            1
# 1      EURO-PCT      DE                 D0       1            1            1
# 2  VOIE DIRECTE      JP                 D0       1            1            1
# 3  VOIE DIRECTE      GB                 D0       1            1            1
# 4  VOIE DIRECTE      DE                 D0       1            1            1
#
#   FISRT_APP_COUNTRY FISRT_APP_TYPE LANGUAGE_OF_FILLING FIRST_CLASSE  \
# 0                US       COMPAGNY                  en     A61K9/48
# 1                DE       COMPAGNY                  de    C08G65/26
# 2                JP       COMPAGNY                  en    G11B15/07
# 3                GB       COMPAGNY                  en    F25B41/04
# 4                DE       COMPAGNY                  de    H01F17/06
#
#       ...       oecd_NB_BACKWARD_NPL  IDX_ORIGIN  SOURCE_IDX_ORI  IDX_RADIC  \
# 0     ...                      0.000    1.000000           IMPUT       1.00
# 1     ...                      0.000    1.000000           IMPUT       1.00
# 2     ...                      0.125    0.897778            CALC       1.00
# 3     ...                      0.000    1.000000           IMPUT       1.00
# 4     ...                      0.000    0.625000            CALC       0.25
#
#   SOURCE_IDX_RAD VARIABLE_CIBLE PRIORITY_MONTH  FILING_MONTH  \
# 0          IMPUT        GRANTED        09/1995       08/1996
# 1          IMPUT        GRANTED        11/1999       11/2000
# 2          IMPUT        GRANTED        06/1992       05/1993
# 3          IMPUT        GRANTED        05/1994       05/1995
# 4           CALC        GRANTED        12/1988       11/1989
#
#    PUBLICATION_MONTH  BEGIN_MONTH
# 0            03/1997      09/1995
# 1            05/2001      11/1999
# 2            12/1993      06/1992
# 3            11/1995      05/1994
# 4            06/1990      12/1988
#
# [5 rows x 50 columns]

# %%
print('n_samples : %d, n_variables : %d' % dataframe.shape)
# Out:
# n_samples : 259431, n_variables : 50

# %%
numerical = ['APP_NB', 'APP_NB_PAYS', 'APP_NB_TYPE', 'NB_CLASSES', 'NB_ROOT_CLASSES', 'NB_SECTORS', 'NB_FIELDS', 
        'INV_NB', 'INV_NB_PAYS',
        'INV_NB_TYPE', 'cited_n', 'cited_nmiss', 'cited_age_min', 'cited_age_median', 'cited_age_max', 'cited_age_mean',
        'cited_age_std', 'NB_BACKWARD_NPL', 'NB_BACKWARD_XY', 'NB_BACKWARD_I', 'NB_BACKWARD_AUTRE', 'NB_BACKWARD_PL', 
        'NB_BACKWARD', 'pct_NB_IPC', 'pct_NB_IPC_LY', 'oecd_NB_ROOT_CLASSES', 'oecd_NB_BACKWARD_PL', 
        'oecd_NB_BACKWARD_NPL', 'IDX_ORIGIN', 'IDX_RADIC']

categories = ['SOURCE_BEGIN_MONTH', 'VOIE_DEPOT', 'LANGUAGE_OF_FILLING', 'COUNTRY', 'FISRT_APP_COUNTRY', 
        'FISRT_APP_TYPE',
        'TECHNOLOGIE_SECTOR', 'TECHNOLOGIE_FIELD', 'FISRT_INV_COUNTRY', 'FISRT_INV_TYPE', 'SOURCE_CITED_AGE', 
        'SOURCE_IDX_ORI', 'SOURCE_IDX_RAD', 'MAIN_IPC', 'FIRST_CLASSE']

dates = ['PRIORITY_MONTH', 'FILING_MONTH', 'PUBLICATION_MONTH', 'BEGIN_MONTH']


# We convert dates to integer: month + year * 12

def convert(s):
    if not pd.isnull(s):
        r = s.split('/')
        return int(r[0]) + 12 * int(r[1])
    else:
        return np.nan


for column in dates:
    dataframe[column] = dataframe[column].apply(convert)
    df_test[column] = df_test[column].apply(convert)
    
# We replace the missing values in the numerical features by the mean of the column

for num in numerical:
    dataframe[num][dataframe[num] == np.nan] = dataframe[num].mean()
    df_test[num][df_test[num] == np.nan] = df_test[num].mean()

# Normalization for numerical values

dataframe[numerical] = (dataframe[numerical] - dataframe[numerical].mean()) / dataframe[numerical].std()
df_test[numerical] = (df_test[numerical] - df_test[numerical].mean()) / df_test[numerical].std()

# We group the numerical and dates features

X = np.concatenate([dataframe[numerical].values, dataframe[dates].values], axis = 1)
X_test = np.concatenate([df_test[numerical].values, df_test[dates].values], axis = 1)


# We transform each categorial variable into indicator variables

for cat in categories:
    counts = pd.value_counts(pd.concat([dataframe[cat], df_test[cat]], axis = 0))

    if cat == 'FIRST_CLASSE':
        ratio = 20
    elif cat == 'MAIN_IPC':
        ratio = 20
    else:
        ratio = 1000
        
    # We keep the most relevant categories
    
    columns_to_keep = counts[counts > counts[0]/ratio].index

    mask = ~dataframe[cat].isin(columns_to_keep)
    
    # We replace the less relevant categories by "x" : category "other"
    
    if cat == 'SOURCE_BEGIN_MONTH': # so that X and X_test have the same number of features
        dataframe[cat][mask] = "D0"
    else:
        dataframe[cat][mask] = "x"
    
    mask_test = ~df_test[cat].isin(columns_to_keep)
    df_test[cat][mask_test] = "x"
    
    # get_dummies create one feature for each category
    
    X_test = np.concatenate([X_test, pd.get_dummies(df_test[cat]).astype(np.int8).values], axis = 1)
    X = np.concatenate([X, pd.get_dummies(dataframe[cat]).astype(np.int8).values], axis = 1)

# The label

y = dataframe.VARIABLE_CIBLE == 'GRANTED'

X_real_test = X_test
# Out:
# C:\Users\Samuel\Anaconda3\lib\site-packages\ipykernel\__main__.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Samuel\Anaconda3\lib\site-packages\ipykernel\__main__.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Samuel\Anaconda3\lib\site-packages\ipykernel\__main__.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Samuel\Anaconda3\lib\site-packages\ipykernel\__main__.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Samuel\Anaconda3\lib\site-packages\ipykernel\__main__.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# We check that the number of features is the same

print(X.shape)
print(X_test.shape)
# Out:
# (259431, 767)
# (129715, 767)

# %%
from sklearn.cross_validation import train_test_split

# CV Set and train set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Right format for xgboost

import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label = y_train)
dtest = xgb.DMatrix(X_test, label = y_test)

# %%
param = {'max_depth':7, 'eta':0.1, 'lambda' : 2, 'min_child_weight': 1, 'alpha': 2, 'silent':1, 'objective':'binary:logistic' }
# 'bst:min_child_weight': 0.5, 'bst:subsample': 0.5, 'colsample_bytree' : 0.8 
param['nthread'] = 4
param['eval_metric'] = 'auc'

evallist  = [(dtest,'eval'), (dtrain,'train')]

num_round = 604
bst = xgb.train( param, dtrain, num_round, evallist )
# Out:
# [0]	eval-auc:0.656285	train-auc:0.662818
# [1]	eval-auc:0.664910	train-auc:0.672242
# [2]	eval-auc:0.667440	train-auc:0.673971
# [3]	eval-auc:0.669805	train-auc:0.676350
# [4]	eval-auc:0.671737	train-auc:0.678322
# [5]	eval-auc:0.672905	train-auc:0.680150
# [6]	eval-auc:0.675350	train-auc:0.683233
# [7]	eval-auc:0.676825	train-auc:0.684732
# [8]	eval-auc:0.677930	train-auc:0.686328
# [9]	eval-auc:0.678980	train-auc:0.687748
# [10]	eval-auc:0.680854	train-auc:0.690005
# [11]	eval-auc:0.681733	train-auc:0.691245
# [12]	eval-auc:0.682986	train-auc:0.692646
# [13]	eval-auc:0.685782	train-auc:0.695517
# [14]	eval-auc:0.687063	train-auc:0.697064
# [15]	eval-auc:0.687507	train-auc:0.697758
# [16]	eval-auc:0.687986	train-auc:0.698715
# [17]	eval-auc:0.688908	train-auc:0.699662
# [18]	eval-auc:0.689714	train-auc:0.700844
# [19]	eval-auc:0.690929	train-auc:0.702122
# [20]	eval-auc:0.691359	train-auc:0.702877
# [21]	eval-auc:0.692169	train-auc:0.704017
# [22]	eval-auc:0.692683	train-auc:0.704889
# [23]	eval-auc:0.693463	train-auc:0.705864
# [24]	eval-auc:0.693885	train-auc:0.706626
# [25]	eval-auc:0.694254	train-auc:0.707142
# [26]	eval-auc:0.694688	train-auc:0.707749
# [27]	eval-auc:0.695090	train-auc:0.708358
# [28]	eval-auc:0.695475	train-auc:0.708807
# [29]	eval-auc:0.695922	train-auc:0.709545
# [30]	eval-auc:0.696273	train-auc:0.710001
# [31]	eval-auc:0.696951	train-auc:0.710948
# [32]	eval-auc:0.697317	train-auc:0.711413
# [33]	eval-auc:0.697570	train-auc:0.711829
# [34]	eval-auc:0.698050	train-auc:0.712301
# [35]	eval-auc:0.698519	train-auc:0.713018
# [36]	eval-auc:0.698722	train-auc:0.713423
# [37]	eval-auc:0.699052	train-auc:0.713915
# [38]	eval-auc:0.699219	train-auc:0.714272
# [39]	eval-auc:0.699452	train-auc:0.714700
# [40]	eval-auc:0.699671	train-auc:0.715032
# [41]	eval-auc:0.699918	train-auc:0.715382
# [42]	eval-auc:0.700120	train-auc:0.715791
# [43]	eval-auc:0.700288	train-auc:0.716190
# [44]	eval-auc:0.700837	train-auc:0.716875
# [45]	eval-auc:0.701024	train-auc:0.717218
# [46]	eval-auc:0.701335	train-auc:0.717497
# [47]	eval-auc:0.701507	train-auc:0.717868
# [48]	eval-auc:0.701718	train-auc:0.718158
# [49]	eval-auc:0.701950	train-auc:0.718535
# [50]	eval-auc:0.702156	train-auc:0.718903
# [51]	eval-auc:0.702270	train-auc:0.719104
# [52]	eval-auc:0.702428	train-auc:0.719349
# [53]	eval-auc:0.702584	train-auc:0.719632
# [54]	eval-auc:0.702708	train-auc:0.719863
# [55]	eval-auc:0.702947	train-auc:0.720182
# [56]	eval-auc:0.703070	train-auc:0.720380
# [57]	eval-auc:0.703177	train-auc:0.720617
# [58]	eval-auc:0.703275	train-auc:0.720849
# [59]	eval-auc:0.703420	train-auc:0.721140
# [60]	eval-auc:0.703669	train-auc:0.721605
# [61]	eval-auc:0.703744	train-auc:0.721851
# [62]	eval-auc:0.703897	train-auc:0.722172
# [63]	eval-auc:0.704081	train-auc:0.722524
# [64]	eval-auc:0.704161	train-auc:0.722720
# [65]	eval-auc:0.704193	train-auc:0.722854
# [66]	eval-auc:0.704470	train-auc:0.723188
# [67]	eval-auc:0.704511	train-auc:0.723315
# [68]	eval-auc:0.704576	train-auc:0.723569
# [69]	eval-auc:0.704869	train-auc:0.723873
# [70]	eval-auc:0.705043	train-auc:0.724188
# [71]	eval-auc:0.705091	train-auc:0.724287
# [72]	eval-auc:0.705293	train-auc:0.724607
# [73]	eval-auc:0.705361	train-auc:0.724916
# [74]	eval-auc:0.705523	train-auc:0.725325
# [75]	eval-auc:0.705663	train-auc:0.725625
# [76]	eval-auc:0.705719	train-auc:0.725830
# [77]	eval-auc:0.705768	train-auc:0.725991
# [78]	eval-auc:0.705867	train-auc:0.726210
# [79]	eval-auc:0.706107	train-auc:0.726506
# [80]	eval-auc:0.706239	train-auc:0.726724
# [81]	eval-auc:0.706263	train-auc:0.726831
# [82]	eval-auc:0.706398	train-auc:0.727145
# [83]	eval-auc:0.706406	train-auc:0.727312
# [84]	eval-auc:0.706506	train-auc:0.727503
# [85]	eval-auc:0.706563	train-auc:0.727635
# [86]	eval-auc:0.706661	train-auc:0.727841
# [87]	eval-auc:0.706723	train-auc:0.727968
# [88]	eval-auc:0.706744	train-auc:0.728190
# [89]	eval-auc:0.706730	train-auc:0.728379
# [90]	eval-auc:0.706760	train-auc:0.728522
# [91]	eval-auc:0.706817	train-auc:0.728722
# [92]	eval-auc:0.706856	train-auc:0.728819
# [93]	eval-auc:0.706927	train-auc:0.729011
# [94]	eval-auc:0.706986	train-auc:0.729235
# [95]	eval-auc:0.707055	train-auc:0.729360
# [96]	eval-auc:0.707118	train-auc:0.729502
# [97]	eval-auc:0.707228	train-auc:0.729617
# [98]	eval-auc:0.707438	train-auc:0.729851
# [99]	eval-auc:0.707462	train-auc:0.730074
# [100]	eval-auc:0.707527	train-auc:0.730326
# [101]	eval-auc:0.707562	train-auc:0.730491
# [102]	eval-auc:0.707637	train-auc:0.730695
# [103]	eval-auc:0.707676	train-auc:0.730793
# [104]	eval-auc:0.707773	train-auc:0.730931
# [105]	eval-auc:0.707792	train-auc:0.730982
# [106]	eval-auc:0.707852	train-auc:0.731119
# [107]	eval-auc:0.707965	train-auc:0.731403
# [108]	eval-auc:0.708018	train-auc:0.731784
# [109]	eval-auc:0.708073	train-auc:0.731969
# [110]	eval-auc:0.708100	train-auc:0.732099
# [111]	eval-auc:0.708117	train-auc:0.732226
# [112]	eval-auc:0.708163	train-auc:0.732329
# [113]	eval-auc:0.708227	train-auc:0.732528
# [114]	eval-auc:0.708233	train-auc:0.732750
# [115]	eval-auc:0.708248	train-auc:0.732816
# [116]	eval-auc:0.708304	train-auc:0.732983
# [117]	eval-auc:0.708344	train-auc:0.733088
# [118]	eval-auc:0.708361	train-auc:0.733170
# [119]	eval-auc:0.708397	train-auc:0.733302
# [120]	eval-auc:0.708393	train-auc:0.733417
# [121]	eval-auc:0.708439	train-auc:0.733761
# [122]	eval-auc:0.708495	train-auc:0.733934
# [123]	eval-auc:0.708597	train-auc:0.734112
# [124]	eval-auc:0.708606	train-auc:0.734230
# [125]	eval-auc:0.708684	train-auc:0.734508
# [126]	eval-auc:0.708715	train-auc:0.734653
# [127]	eval-auc:0.708730	train-auc:0.734711
# [128]	eval-auc:0.708757	train-auc:0.734886
# [129]	eval-auc:0.708839	train-auc:0.735157
# [130]	eval-auc:0.708906	train-auc:0.735209
# [131]	eval-auc:0.708925	train-auc:0.735302
# [132]	eval-auc:0.708952	train-auc:0.735487
# [133]	eval-auc:0.708960	train-auc:0.735539
# [134]	eval-auc:0.709055	train-auc:0.735727
# [135]	eval-auc:0.709204	train-auc:0.736063
# [136]	eval-auc:0.709236	train-auc:0.736149
# [137]	eval-auc:0.709232	train-auc:0.736289
# [138]	eval-auc:0.709244	train-auc:0.736442
# [139]	eval-auc:0.709300	train-auc:0.736577
# [140]	eval-auc:0.709299	train-auc:0.736615
# [141]	eval-auc:0.709403	train-auc:0.736821
# [142]	eval-auc:0.709434	train-auc:0.736920
# [143]	eval-auc:0.709484	train-auc:0.736987
# [144]	eval-auc:0.709625	train-auc:0.737223
# [145]	eval-auc:0.709623	train-auc:0.737285
# [146]	eval-auc:0.709588	train-auc:0.737404
# [147]	eval-auc:0.709600	train-auc:0.737484
# [148]	eval-auc:0.709658	train-auc:0.737706
# [149]	eval-auc:0.709679	train-auc:0.737773
# [150]	eval-auc:0.709682	train-auc:0.737826
# [151]	eval-auc:0.709716	train-auc:0.737950
# [152]	eval-auc:0.709749	train-auc:0.738087
# [153]	eval-auc:0.709742	train-auc:0.738147
# [154]	eval-auc:0.709770	train-auc:0.738197
# [155]	eval-auc:0.709779	train-auc:0.738298
# [156]	eval-auc:0.709770	train-auc:0.738447
# [157]	eval-auc:0.709822	train-auc:0.738607
# [158]	eval-auc:0.709885	train-auc:0.738710
# [159]	eval-auc:0.709881	train-auc:0.738811
# [160]	eval-auc:0.709867	train-auc:0.738964
# [161]	eval-auc:0.709964	train-auc:0.739180
# [162]	eval-auc:0.709954	train-auc:0.739292
# [163]	eval-auc:0.709936	train-auc:0.739410
# [164]	eval-auc:0.709944	train-auc:0.739470
# [165]	eval-auc:0.709959	train-auc:0.739633
# [166]	eval-auc:0.710009	train-auc:0.739843
# [167]	eval-auc:0.710070	train-auc:0.740005
# [168]	eval-auc:0.710108	train-auc:0.740119
# [169]	eval-auc:0.710149	train-auc:0.740216
# [170]	eval-auc:0.710156	train-auc:0.740266
# [171]	eval-auc:0.710174	train-auc:0.740373
# [172]	eval-auc:0.710189	train-auc:0.740494
# [173]	eval-auc:0.710181	train-auc:0.740526
# [174]	eval-auc:0.710217	train-auc:0.740603
# [175]	eval-auc:0.710228	train-auc:0.740638
# [176]	eval-auc:0.710292	train-auc:0.740787
# [177]	eval-auc:0.710334	train-auc:0.741010
# [178]	eval-auc:0.710408	train-auc:0.741134
# [179]	eval-auc:0.710411	train-auc:0.741248
# [180]	eval-auc:0.710418	train-auc:0.741426
# [181]	eval-auc:0.710469	train-auc:0.741540
# [182]	eval-auc:0.710476	train-auc:0.741612
# [183]	eval-auc:0.710499	train-auc:0.741711
# [184]	eval-auc:0.710525	train-auc:0.741878
# [185]	eval-auc:0.710532	train-auc:0.741923
# [186]	eval-auc:0.710535	train-auc:0.741977
# [187]	eval-auc:0.710548	train-auc:0.742024
# [188]	eval-auc:0.710569	train-auc:0.742149
# [189]	eval-auc:0.710632	train-auc:0.742273
# [190]	eval-auc:0.710604	train-auc:0.742360
# [191]	eval-auc:0.710707	train-auc:0.742514
# [192]	eval-auc:0.710720	train-auc:0.742613
# [193]	eval-auc:0.710816	train-auc:0.742869
# [194]	eval-auc:0.710843	train-auc:0.743037
# [195]	eval-auc:0.710844	train-auc:0.743079
# [196]	eval-auc:0.710867	train-auc:0.743329
# [197]	eval-auc:0.710906	train-auc:0.743486
# [198]	eval-auc:0.710926	train-auc:0.743594
# [199]	eval-auc:0.710931	train-auc:0.743755
# [200]	eval-auc:0.710918	train-auc:0.743785
# [201]	eval-auc:0.711013	train-auc:0.744079
# [202]	eval-auc:0.711056	train-auc:0.744194
# [203]	eval-auc:0.711090	train-auc:0.744394
# [204]	eval-auc:0.711168	train-auc:0.744531
# [205]	eval-auc:0.711158	train-auc:0.744570
# [206]	eval-auc:0.711144	train-auc:0.744698
# [207]	eval-auc:0.711168	train-auc:0.744746
# [208]	eval-auc:0.711187	train-auc:0.744894
# [209]	eval-auc:0.711192	train-auc:0.744969
# [210]	eval-auc:0.711196	train-auc:0.745208
# [211]	eval-auc:0.711188	train-auc:0.745260
# [212]	eval-auc:0.711188	train-auc:0.745303
# [213]	eval-auc:0.711192	train-auc:0.745422
# [214]	eval-auc:0.711225	train-auc:0.745503
# [215]	eval-auc:0.711239	train-auc:0.745680
# [216]	eval-auc:0.711256	train-auc:0.745795
# [217]	eval-auc:0.711241	train-auc:0.745889
# [218]	eval-auc:0.711348	train-auc:0.746047
# [219]	eval-auc:0.711402	train-auc:0.746133
# [220]	eval-auc:0.711399	train-auc:0.746176
# [221]	eval-auc:0.711452	train-auc:0.746359
# [222]	eval-auc:0.711446	train-auc:0.746405
# [223]	eval-auc:0.711556	train-auc:0.746682
# [224]	eval-auc:0.711568	train-auc:0.746841
# [225]	eval-auc:0.711564	train-auc:0.746881
# [226]	eval-auc:0.711644	train-auc:0.747000
# [227]	eval-auc:0.711682	train-auc:0.747297
# [228]	eval-auc:0.711700	train-auc:0.747397
# [229]	eval-auc:0.711723	train-auc:0.747456
# [230]	eval-auc:0.711774	train-auc:0.747568
# [231]	eval-auc:0.711782	train-auc:0.747686
# [232]	eval-auc:0.711784	train-auc:0.747747
# [233]	eval-auc:0.711788	train-auc:0.747836
# [234]	eval-auc:0.711831	train-auc:0.747919
# [235]	eval-auc:0.711811	train-auc:0.748215
# [236]	eval-auc:0.711841	train-auc:0.748482
# [237]	eval-auc:0.711841	train-auc:0.748502
# [238]	eval-auc:0.711855	train-auc:0.748561
# [239]	eval-auc:0.711827	train-auc:0.748643
# [240]	eval-auc:0.711835	train-auc:0.748765
# [241]	eval-auc:0.711832	train-auc:0.748793
# [242]	eval-auc:0.711834	train-auc:0.748945
# [243]	eval-auc:0.711883	train-auc:0.749065
# [244]	eval-auc:0.711948	train-auc:0.749229
# [245]	eval-auc:0.711946	train-auc:0.749272
# [246]	eval-auc:0.711942	train-auc:0.749322
# [247]	eval-auc:0.711919	train-auc:0.749443
# [248]	eval-auc:0.711939	train-auc:0.749668
# [249]	eval-auc:0.711976	train-auc:0.749768
# [250]	eval-auc:0.712031	train-auc:0.750019
# [251]	eval-auc:0.712070	train-auc:0.750117
# [252]	eval-auc:0.712079	train-auc:0.750237
# [253]	eval-auc:0.712083	train-auc:0.750287
# [254]	eval-auc:0.712096	train-auc:0.750423
# [255]	eval-auc:0.712159	train-auc:0.750592
# [256]	eval-auc:0.712155	train-auc:0.750796
# [257]	eval-auc:0.712180	train-auc:0.751157
# [258]	eval-auc:0.712196	train-auc:0.751223
# [259]	eval-auc:0.712213	train-auc:0.751288
# [260]	eval-auc:0.712220	train-auc:0.751333
# [261]	eval-auc:0.712229	train-auc:0.751449
# [262]	eval-auc:0.712237	train-auc:0.751552
# [263]	eval-auc:0.712266	train-auc:0.751617
# [264]	eval-auc:0.712263	train-auc:0.751694
# [265]	eval-auc:0.712286	train-auc:0.751806
# [266]	eval-auc:0.712281	train-auc:0.751923
# [267]	eval-auc:0.712284	train-auc:0.752025
# [268]	eval-auc:0.712281	train-auc:0.752156
# [269]	eval-auc:0.712284	train-auc:0.752223
# [270]	eval-auc:0.712313	train-auc:0.752313
# [271]	eval-auc:0.712330	train-auc:0.752424
# [272]	eval-auc:0.712340	train-auc:0.752516
# [273]	eval-auc:0.712335	train-auc:0.752551
# [274]	eval-auc:0.712337	train-auc:0.752768
# [275]	eval-auc:0.712349	train-auc:0.752917
# [276]	eval-auc:0.712374	train-auc:0.753059
# [277]	eval-auc:0.712366	train-auc:0.753088
# [278]	eval-auc:0.712376	train-auc:0.753291
# [279]	eval-auc:0.712394	train-auc:0.753472
# [280]	eval-auc:0.712413	train-auc:0.753592
# [281]	eval-auc:0.712415	train-auc:0.753624
# [282]	eval-auc:0.712404	train-auc:0.753698
# [283]	eval-auc:0.712396	train-auc:0.753764
# [284]	eval-auc:0.712422	train-auc:0.753796
# [285]	eval-auc:0.712440	train-auc:0.753847
# [286]	eval-auc:0.712439	train-auc:0.753873
# [287]	eval-auc:0.712451	train-auc:0.754044
# [288]	eval-auc:0.712477	train-auc:0.754114
# [289]	eval-auc:0.712464	train-auc:0.754206
# [290]	eval-auc:0.712467	train-auc:0.754277
# [291]	eval-auc:0.712467	train-auc:0.754525
# [292]	eval-auc:0.712470	train-auc:0.754612
# [293]	eval-auc:0.712470	train-auc:0.754641
# [294]	eval-auc:0.712489	train-auc:0.754720
# [295]	eval-auc:0.712493	train-auc:0.754796
# [296]	eval-auc:0.712501	train-auc:0.754852
# [297]	eval-auc:0.712495	train-auc:0.754920
# [298]	eval-auc:0.712514	train-auc:0.755015
# [299]	eval-auc:0.712521	train-auc:0.755070
# [300]	eval-auc:0.712533	train-auc:0.755126
# [301]	eval-auc:0.712546	train-auc:0.755260
# [302]	eval-auc:0.712538	train-auc:0.755540
# [303]	eval-auc:0.712565	train-auc:0.755670
# [304]	eval-auc:0.712594	train-auc:0.755845
# [305]	eval-auc:0.712617	train-auc:0.755886
# [306]	eval-auc:0.712620	train-auc:0.755906
# [307]	eval-auc:0.712645	train-auc:0.756026
# [308]	eval-auc:0.712644	train-auc:0.756133
# [309]	eval-auc:0.712647	train-auc:0.756175
# [310]	eval-auc:0.712706	train-auc:0.756308
# [311]	eval-auc:0.712717	train-auc:0.756375
# [312]	eval-auc:0.712720	train-auc:0.756508
# [313]	eval-auc:0.712729	train-auc:0.756617
# [314]	eval-auc:0.712741	train-auc:0.756765
# [315]	eval-auc:0.712761	train-auc:0.756972
# [316]	eval-auc:0.712758	train-auc:0.757004
# [317]	eval-auc:0.712774	train-auc:0.757066
# [318]	eval-auc:0.712771	train-auc:0.757094
# [319]	eval-auc:0.712757	train-auc:0.757175
# [320]	eval-auc:0.712762	train-auc:0.757277
# [321]	eval-auc:0.712793	train-auc:0.757452
# [322]	eval-auc:0.712799	train-auc:0.757477
# [323]	eval-auc:0.712776	train-auc:0.757591
# [324]	eval-auc:0.712817	train-auc:0.757822
# [325]	eval-auc:0.712829	train-auc:0.758027
# [326]	eval-auc:0.712809	train-auc:0.758145
# [327]	eval-auc:0.712812	train-auc:0.758190
# [328]	eval-auc:0.712817	train-auc:0.758232
# [329]	eval-auc:0.712807	train-auc:0.758282
# [330]	eval-auc:0.712818	train-auc:0.758337
# [331]	eval-auc:0.712849	train-auc:0.758421
# [332]	eval-auc:0.712809	train-auc:0.758552
# [333]	eval-auc:0.712811	train-auc:0.758585
# [334]	eval-auc:0.712855	train-auc:0.758765
# [335]	eval-auc:0.712852	train-auc:0.758822
# [336]	eval-auc:0.712838	train-auc:0.759003
# [337]	eval-auc:0.712811	train-auc:0.759151
# [338]	eval-auc:0.712847	train-auc:0.759328
# [339]	eval-auc:0.712854	train-auc:0.759353
# [340]	eval-auc:0.712865	train-auc:0.759417
# [341]	eval-auc:0.712935	train-auc:0.759575
# [342]	eval-auc:0.712927	train-auc:0.759598
# [343]	eval-auc:0.712918	train-auc:0.759685
# [344]	eval-auc:0.712937	train-auc:0.759810
# [345]	eval-auc:0.712959	train-auc:0.759860
# [346]	eval-auc:0.712981	train-auc:0.759920
# [347]	eval-auc:0.712993	train-auc:0.760006
# [348]	eval-auc:0.712989	train-auc:0.760030
# [349]	eval-auc:0.712997	train-auc:0.760185
# [350]	eval-auc:0.712980	train-auc:0.760464
# [351]	eval-auc:0.712999	train-auc:0.760615
# [352]	eval-auc:0.713012	train-auc:0.760654
# [353]	eval-auc:0.713020	train-auc:0.760683
# [354]	eval-auc:0.713057	train-auc:0.760723
# [355]	eval-auc:0.713090	train-auc:0.760845
# [356]	eval-auc:0.713085	train-auc:0.760879
# [357]	eval-auc:0.713092	train-auc:0.760922
# [358]	eval-auc:0.713117	train-auc:0.761071
# [359]	eval-auc:0.713129	train-auc:0.761204
# [360]	eval-auc:0.713142	train-auc:0.761323
# [361]	eval-auc:0.713161	train-auc:0.761515
# [362]	eval-auc:0.713153	train-auc:0.761576
# [363]	eval-auc:0.713182	train-auc:0.761727
# [364]	eval-auc:0.713203	train-auc:0.761821
# [365]	eval-auc:0.713205	train-auc:0.761905
# [366]	eval-auc:0.713213	train-auc:0.762107
# [367]	eval-auc:0.713212	train-auc:0.762351
# [368]	eval-auc:0.713210	train-auc:0.762398
# [369]	eval-auc:0.713216	train-auc:0.762451
# [370]	eval-auc:0.713236	train-auc:0.762576
# [371]	eval-auc:0.713249	train-auc:0.762627
# [372]	eval-auc:0.713257	train-auc:0.762662
# [373]	eval-auc:0.713239	train-auc:0.762741
# [374]	eval-auc:0.713258	train-auc:0.762822
# [375]	eval-auc:0.713235	train-auc:0.762945
# [376]	eval-auc:0.713232	train-auc:0.762961
# [377]	eval-auc:0.713226	train-auc:0.763092
# [378]	eval-auc:0.713234	train-auc:0.763207
# [379]	eval-auc:0.713244	train-auc:0.763345
# [380]	eval-auc:0.713300	train-auc:0.763406
# [381]	eval-auc:0.713289	train-auc:0.763466
# [382]	eval-auc:0.713300	train-auc:0.763575
# [383]	eval-auc:0.713297	train-auc:0.763656
# [384]	eval-auc:0.713291	train-auc:0.763697
# [385]	eval-auc:0.713271	train-auc:0.763773
# [386]	eval-auc:0.713260	train-auc:0.763826
# [387]	eval-auc:0.713269	train-auc:0.763932
# [388]	eval-auc:0.713309	train-auc:0.764071
# [389]	eval-auc:0.713303	train-auc:0.764119
# [390]	eval-auc:0.713305	train-auc:0.764150
# [391]	eval-auc:0.713315	train-auc:0.764225
# [392]	eval-auc:0.713331	train-auc:0.764313
# [393]	eval-auc:0.713318	train-auc:0.764393
# [394]	eval-auc:0.713341	train-auc:0.764558
# [395]	eval-auc:0.713337	train-auc:0.764636
# [396]	eval-auc:0.713330	train-auc:0.764809
# [397]	eval-auc:0.713331	train-auc:0.764840
# [398]	eval-auc:0.713322	train-auc:0.764912
# [399]	eval-auc:0.713317	train-auc:0.764990
# [400]	eval-auc:0.713322	train-auc:0.765060
# [401]	eval-auc:0.713333	train-auc:0.765127
# [402]	eval-auc:0.713350	train-auc:0.765156
# [403]	eval-auc:0.713348	train-auc:0.765164
# [404]	eval-auc:0.713351	train-auc:0.765238
# [405]	eval-auc:0.713407	train-auc:0.765321
# [406]	eval-auc:0.713420	train-auc:0.765368
# [407]	eval-auc:0.713460	train-auc:0.765503
# [408]	eval-auc:0.713469	train-auc:0.765518
# [409]	eval-auc:0.713488	train-auc:0.765572
# [410]	eval-auc:0.713514	train-auc:0.765686
# [411]	eval-auc:0.713514	train-auc:0.765733
# [412]	eval-auc:0.713516	train-auc:0.765822
# [413]	eval-auc:0.713538	train-auc:0.765908
# [414]	eval-auc:0.713542	train-auc:0.766091
# [415]	eval-auc:0.713537	train-auc:0.766136
# [416]	eval-auc:0.713554	train-auc:0.766301
# [417]	eval-auc:0.713557	train-auc:0.766405
# [418]	eval-auc:0.713551	train-auc:0.766474
# [419]	eval-auc:0.713569	train-auc:0.766553
# [420]	eval-auc:0.713574	train-auc:0.766573
# [421]	eval-auc:0.713571	train-auc:0.766692
# [422]	eval-auc:0.713570	train-auc:0.766832
# [423]	eval-auc:0.713602	train-auc:0.766890
# [424]	eval-auc:0.713600	train-auc:0.767034
# [425]	eval-auc:0.713606	train-auc:0.767070
# [426]	eval-auc:0.713603	train-auc:0.767154
# [427]	eval-auc:0.713612	train-auc:0.767199
# [428]	eval-auc:0.713622	train-auc:0.767297
# [429]	eval-auc:0.713627	train-auc:0.767408
# [430]	eval-auc:0.713604	train-auc:0.767475
# [431]	eval-auc:0.713671	train-auc:0.767737
# [432]	eval-auc:0.713610	train-auc:0.767946
# [433]	eval-auc:0.713613	train-auc:0.768081
# [434]	eval-auc:0.713605	train-auc:0.768223
# [435]	eval-auc:0.713602	train-auc:0.768305
# [436]	eval-auc:0.713617	train-auc:0.768383
# [437]	eval-auc:0.713624	train-auc:0.768616
# [438]	eval-auc:0.713664	train-auc:0.768708
# [439]	eval-auc:0.713673	train-auc:0.768756
# [440]	eval-auc:0.713726	train-auc:0.768928
# [441]	eval-auc:0.713739	train-auc:0.769099
# [442]	eval-auc:0.713757	train-auc:0.769225
# [443]	eval-auc:0.713779	train-auc:0.769371
# [444]	eval-auc:0.713749	train-auc:0.769507
# [445]	eval-auc:0.713757	train-auc:0.769657
# [446]	eval-auc:0.713796	train-auc:0.769805
# [447]	eval-auc:0.713779	train-auc:0.769939
# [448]	eval-auc:0.713796	train-auc:0.770104
# [449]	eval-auc:0.713792	train-auc:0.770150
# [450]	eval-auc:0.713816	train-auc:0.770241
# [451]	eval-auc:0.713814	train-auc:0.770391
# [452]	eval-auc:0.713896	train-auc:0.770628
# [453]	eval-auc:0.713839	train-auc:0.770862
# [454]	eval-auc:0.713833	train-auc:0.770994
# [455]	eval-auc:0.713831	train-auc:0.771113
# [456]	eval-auc:0.713829	train-auc:0.771204
# [457]	eval-auc:0.713820	train-auc:0.771385
# [458]	eval-auc:0.713805	train-auc:0.771533
# [459]	eval-auc:0.713786	train-auc:0.771676
# [460]	eval-auc:0.713804	train-auc:0.771807
# [461]	eval-auc:0.713804	train-auc:0.772023
# [462]	eval-auc:0.713788	train-auc:0.772088
# [463]	eval-auc:0.713752	train-auc:0.772247
# [464]	eval-auc:0.713779	train-auc:0.772355
# [465]	eval-auc:0.713751	train-auc:0.772478
# [466]	eval-auc:0.713750	train-auc:0.772555
# [467]	eval-auc:0.713740	train-auc:0.772826
# [468]	eval-auc:0.713744	train-auc:0.772876
# [469]	eval-auc:0.713745	train-auc:0.772916
# [470]	eval-auc:0.713761	train-auc:0.773046
# [471]	eval-auc:0.713833	train-auc:0.773255
# [472]	eval-auc:0.713815	train-auc:0.773485
# [473]	eval-auc:0.713790	train-auc:0.773649
# [474]	eval-auc:0.713743	train-auc:0.773868
# [475]	eval-auc:0.713736	train-auc:0.773941
# [476]	eval-auc:0.713781	train-auc:0.774092
# [477]	eval-auc:0.713781	train-auc:0.774154
# [478]	eval-auc:0.713773	train-auc:0.774186
# [479]	eval-auc:0.713847	train-auc:0.774349
# [480]	eval-auc:0.713890	train-auc:0.774510
# [481]	eval-auc:0.713899	train-auc:0.774621
# [482]	eval-auc:0.713899	train-auc:0.774651
# [483]	eval-auc:0.713884	train-auc:0.774728
# [484]	eval-auc:0.713877	train-auc:0.774751
# [485]	eval-auc:0.713889	train-auc:0.774822
# [486]	eval-auc:0.713890	train-auc:0.774882
# [487]	eval-auc:0.713890	train-auc:0.774915
# [488]	eval-auc:0.713885	train-auc:0.774990
# [489]	eval-auc:0.713903	train-auc:0.775041
# [490]	eval-auc:0.713931	train-auc:0.775155
# [491]	eval-auc:0.713926	train-auc:0.775216
# [492]	eval-auc:0.713918	train-auc:0.775240
# [493]	eval-auc:0.713924	train-auc:0.775281
# [494]	eval-auc:0.713902	train-auc:0.775338
# [495]	eval-auc:0.713890	train-auc:0.775410
# [496]	eval-auc:0.713891	train-auc:0.775531
# [497]	eval-auc:0.713875	train-auc:0.775620
# [498]	eval-auc:0.713872	train-auc:0.775790
# [499]	eval-auc:0.713879	train-auc:0.775900
# [500]	eval-auc:0.713881	train-auc:0.775928
# [501]	eval-auc:0.713858	train-auc:0.776018
# [502]	eval-auc:0.713877	train-auc:0.776154
# [503]	eval-auc:0.713862	train-auc:0.776196
# [504]	eval-auc:0.713874	train-auc:0.776343
# [505]	eval-auc:0.713864	train-auc:0.776447
# [506]	eval-auc:0.713873	train-auc:0.776483
# [507]	eval-auc:0.713890	train-auc:0.776500
# [508]	eval-auc:0.713877	train-auc:0.776561
# [509]	eval-auc:0.713903	train-auc:0.776732

# %%
# GridSearch: very long to run

#from xgboost.sklearn import XGBClassifier
#from sklearn.grid_search import GridSearchCV
#from sklearn.metrics import roc_auc_score

#max_depth = [8,10,12]

#gsearch1 = GridSearchCV(verbose = 10, estimator = XGBClassifier(reg_lambda = 4, reg_alpha = 4, learning_rate = 0.1, n_estimators = 200, max_depth = 5, min_child_weight = 1, gamma = 0, subsample = 0.8, colsample_bytree = 0.8, objective = 'binary:logistic', nthread = 8, scale_pos_weight = 1, seed = 42), param_grid = dict(max_depth = max_depth), scoring = 'roc_auc', n_jobs = 8, iid = False, cv = 3)
#gsearch1.fit(X_train, y_train)
#print(gsearch1.grid_scores_)
#print(gsearch1.best_params_)
#print(gsearch1.best_score_)

# %%
# We predict the values of the test set online

drealtest = xgb.DMatrix(X_real_test)
y_pred = bst.predict(drealtest)

# %%
from sklearn.metrics import roc_auc_score

print('Score sur le cv : %s' % roc_auc_score(y_test, bst.predict(dtest)))
print('Score sur le train : %s' % roc_auc_score(y_train, bst.predict(dtrain)))
# Out:
# Score (optimiste) sur le test : 0.714275401162
# Score (optimiste) sur le train : 0.81605391662

# %%
np.savetxt('y_pred.txt', y_pred, fmt='%s')
